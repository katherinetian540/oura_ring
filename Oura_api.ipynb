# %% [markdown]
# ### Daily Activity
# #### Raw Data

# %%
import requests
import json

# Define the base URL and request parameters
url = 'https://api.ouraring.com/v2/usercollection/daily_activity'
params = {
    'start_date': '2024-12-01',
    'end_date': '2024-12-31'
}

# List of tokens and corresponding names
tokens = [
    {'name': 'UL_0201', 'token': 'UYX2H6CAYY4AQMVQNMZE4YOD6KPH5LLW'},
    {'name': 'UL_0225', 'token': 'BDMJI53UKMV2Y7YNDFO7A2M7T7SPMV3T'},
    {'name': 'UL_0352', 'token': '44S3FRJLZ5O4GLSW4TCFADYBLS3LF7J4'},
    {'name': 'UL_0417', 'token': 'X2JHCUYBMBWX76MGUCOLTG2QV662PNP3'},
    {'name': 'UL_0422', 'token': 'HMAPC24EX54GWTQHA5OEV3IRBVCJTNP2'},
    {'name': 'UL_0480', 'token': 'NV7PNEKQWQCWGMB27I33C7CZI7RPOSAT'},
    {'name': 'UL_1086', 'token': 'PQ4BXQMOOYADESZTUWJX7PZ6H5INMMJT'},
    {'name': 'UL_1184', 'token': 'LHOC324KTFIFSYRNOJGEI6VDK4IFOWBO'},
    {'name': 'UL_9900', 'token': '4EPJOJ6QEBRMM6S7BZJT6Q5U3D3FZKSA'}
]

# Loop through each token and make the API request
for user in tokens:
    headers = {
        'Authorization': f'Bearer {user["token"]}'  
    }

    # Make the API request
    response = requests.get(url, headers=headers, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()

        # Save the data as a JSON file with the user's name in the filename
        file_name = f'/Users/katherinetian/Downloads/Daily Activity/UL/daily_activity_{user["name"]}.json'
        with open(file_name, 'w') as f:
            json.dump(data, f, indent=4)

        print(f'Data saved to {file_name}')

    else:
        # Handle possible errors
        print(f'Error with {user["name"]}: {response.status_code}')
        print(response.text)
# Out:
# Data saved to /Users/katherinetian/Downloads/Daily Activity/UL/daily_activity_UL_0201.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/UL/daily_activity_UL_0225.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/UL/daily_activity_UL_0352.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/UL/daily_activity_UL_0417.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/UL/daily_activity_UL_0422.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/UL/daily_activity_UL_0480.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/UL/daily_activity_UL_1086.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/UL/daily_activity_UL_1184.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/UL/daily_activity_UL_9900.json

# %%
import requests
import json

# Define the base URL and request parameters
url = 'https://api.ouraring.com/v2/usercollection/daily_activity'
params = {
    'start_date': '2024-12-01',
    'end_date': '2024-12-31'
}

# List of tokens and corresponding names
tokens = [
    {'name': 'SA_0071', 'token': 'OOAMM7TFENXQOHAJXYXVKNSOTFDRDXH2'},
    {'name': 'SA_0148', 'token': '3QRJWDU7HG64MNJVXR4AGV2G4TYFW5D2'},
    {'name': 'SA_0243', 'token': 'J7YQ57BYWLAKFGR53UYFQYY5HOFJHMLT'},
    {'name': 'SA_0528', 'token': 'MMFEOJ6VIEYRHNSRLRGVIOC73SHVI4F7'},
    {'name': 'SA_0585', 'token': 'AQMNWCP7QKC26ARO7ZBO56GJAUS2H5VF'},
    {'name': 'SA_0721', 'token': 'IH4FINABW56VPLLDUMAD7UDCNOXDX6FN'},
    {'name': 'SA_0762', 'token': 'IXO53AOR4KENUBKYGFIDAUN3EM6UAPJJ'},
    {'name': 'SA_0811', 'token': 'XDB63PKOCWZ7QNAASIEIMZQPO7NF3VH3'},
    {'name': 'SA_0820', 'token': 'LDQUFVEAP2GVSQXP5CTHZMWLAK2HLX6Y'},
    {'name': 'SA_1173', 'token': 'JNQMINIA52BKXQG5BQFGJGIOCJFMN6SR'},
    {'name': 'SA_1207', 'token': 'G3T7JPRTMKE47I3RQNEWC27R2FP4IA7T'},
    {'name': 'SA_1368', 'token': '3MLB5WN2TD7JXW3TJUPZ4BQ6RM5THTGL'}
]

# Loop through each token and make the API request
for user in tokens:
    headers = {
        'Authorization': f'Bearer {user["token"]}'  
    }

    # Make the API request
    response = requests.get(url, headers=headers, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()

        # Save the data as a JSON file with the user's name in the filename
        file_name = f'/Users/katherinetian/Downloads/Daily Activity/SA/daily_activity_{user["name"]}.json'
        with open(file_name, 'w') as f:
            json.dump(data, f, indent=4)

        print(f'Data saved to {file_name}')

    else:
        # Handle possible errors
        print(f'Error with {user["name"]}: {response.status_code}')
        print(response.text)
# Out:
# Data saved to /Users/katherinetian/Downloads/Daily Activity/SA/daily_activity_SA_0071.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/SA/daily_activity_SA_0148.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/SA/daily_activity_SA_0243.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/SA/daily_activity_SA_0528.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/SA/daily_activity_SA_0585.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/SA/daily_activity_SA_0721.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/SA/daily_activity_SA_0762.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/SA/daily_activity_SA_0811.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/SA/daily_activity_SA_0820.json
# Data saved to /Users/katherinetian/Downloads/Daily Activity/SA/daily_activity_SA_1173.json
# ...

# %% [markdown]
# ## Heartrate

# %%
import requests
import json

# Define the base URL for heart rate data and request parameters
url = 'https://api.ouraring.com/v2/usercollection/heartrate'
params = {
    'start_datetime': '2024-12-01T00:00:00-08:00', 
    'end_datetime': '2024-12-31T00:00:00-08:00'
}

# List of tokens and corresponding names
tokens = [
    {'name': 'UL_0201', 'token': 'UYX2H6CAYY4AQMVQNMZE4YOD6KPH5LLW'},
    {'name': 'UL_0225', 'token': 'BDMJI53UKMV2Y7YNDFO7A2M7T7SPMV3T'},
    {'name': 'UL_0352', 'token': '44S3FRJLZ5O4GLSW4TCFADYBLS3LF7J4'},
    {'name': 'UL_0417', 'token': 'X2JHCUYBMBWX76MGUCOLTG2QV662PNP3'},
    {'name': 'UL_0422', 'token': 'HMAPC24EX54GWTQHA5OEV3IRBVCJTNP2'},
    {'name': 'UL_0480', 'token': 'NV7PNEKQWQCWGMB27I33C7CZI7RPOSAT'},
    {'name': 'UL_1086', 'token': 'PQ4BXQMOOYADESZTUWJX7PZ6H5INMMJT'},
    {'name': 'UL_1184', 'token': 'LHOC324KTFIFSYRNOJGEI6VDK4IFOWBO'},
    {'name': 'UL_9900', 'token': '4EPJOJ6QEBRMM6S7BZJT6Q5U3D3FZKSA'}
]

# Loop through each token and make the API request
for user in tokens:
    headers = {
        'Authorization': f'Bearer {user["token"]}'  
    }

    # Make the API request
    response = requests.get(url, headers=headers, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()

        # Save the data as a JSON file with the user's name in the filename
        file_name = f'/Users/katherinetian/Downloads/heart_rate/UL/heart_rate_{user["name"]}.json'
        with open(file_name, 'w') as f:
            json.dump(data, f, indent=4)

        print(f'Data saved to {file_name}')

    else:
        # Handle possible errors
        print(f'Error with {user["name"]}: {response.status_code}')
        print(response.text)

# Example to test with a token directly (replace <token> with actual token)
headers = { 
  'Authorization': 'Bearer <token>' 
}
response = requests.request('GET', url, headers=headers, params=params) 
print(response.text)
# Out:
# Data saved to /Users/katherinetian/Downloads/heart_rate/UL/heart_rate_UL_0201.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/UL/heart_rate_UL_0225.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/UL/heart_rate_UL_0352.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/UL/heart_rate_UL_0417.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/UL/heart_rate_UL_0422.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/UL/heart_rate_UL_0480.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/UL/heart_rate_UL_1086.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/UL/heart_rate_UL_1184.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/UL/heart_rate_UL_9900.json
# {"message":"The access token provided is expired, revoked, malformed, or invalid for other reasons."}

# %%
import requests
import json

# Define the base URL for heart rate data and request parameters
url = 'https://api.ouraring.com/v2/usercollection/heartrate'
params = {
    'start_datetime': '2024-12-01T00:00:00-08:00', 
    'end_datetime': '2024-12-31T00:00:00-08:00'
}

# List of tokens and corresponding names
tokens = [
    {'name': 'SA_0071', 'token': 'OOAMM7TFENXQOHAJXYXVKNSOTFDRDXH2'},
    {'name': 'SA_0148', 'token': '3QRJWDU7HG64MNJVXR4AGV2G4TYFW5D2'},
    {'name': 'SA_0243', 'token': 'J7YQ57BYWLAKFGR53UYFQYY5HOFJHMLT'},
    {'name': 'SA_0528', 'token': 'MMFEOJ6VIEYRHNSRLRGVIOC73SHVI4F7'},
    {'name': 'SA_0585', 'token': 'AQMNWCP7QKC26ARO7ZBO56GJAUS2H5VF'},
    {'name': 'SA_0721', 'token': 'IH4FINABW56VPLLDUMAD7UDCNOXDX6FN'},
    {'name': 'SA_0762', 'token': 'IXO53AOR4KENUBKYGFIDAUN3EM6UAPJJ'},
    {'name': 'SA_0811', 'token': 'XDB63PKOCWZ7QNAASIEIMZQPO7NF3VH3'},
    {'name': 'SA_0820', 'token': 'LDQUFVEAP2GVSQXP5CTHZMWLAK2HLX6Y'},
    {'name': 'SA_1173', 'token': 'JNQMINIA52BKXQG5BQFGJGIOCJFMN6SR'},
    {'name': 'SA_1207', 'token': 'G3T7JPRTMKE47I3RQNEWC27R2FP4IA7T'},
    {'name': 'SA_1368', 'token': '3MLB5WN2TD7JXW3TJUPZ4BQ6RM5THTGL'}
]

# Loop through each token and make the API request
for user in tokens:
    headers = {
        'Authorization': f'Bearer {user["token"]}'  
    }

    # Make the API request
    response = requests.get(url, headers=headers, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()

        # Save the data as a JSON file with the user's name in the filename
        file_name = f'/Users/katherinetian/Downloads/heart_rate/SA/heart_rate_{user["name"]}.json'
        with open(file_name, 'w') as f:
            json.dump(data, f, indent=4)

        print(f'Data saved to {file_name}')

    else:
        # Handle possible errors
        print(f'Error with {user["name"]}: {response.status_code}')
        print(response.text)

# Example to test with a token directly (replace <token> with actual token)
headers = { 
  'Authorization': 'Bearer <token>' 
}
response = requests.request('GET', url, headers=headers, params=params) 
print(response.text)
# Out:
# Data saved to /Users/katherinetian/Downloads/heart_rate/SA/heart_rate_SA_0071.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/SA/heart_rate_SA_0148.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/SA/heart_rate_SA_0243.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/SA/heart_rate_SA_0528.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/SA/heart_rate_SA_0585.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/SA/heart_rate_SA_0721.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/SA/heart_rate_SA_0762.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/SA/heart_rate_SA_0811.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/SA/heart_rate_SA_0820.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/SA/heart_rate_SA_1173.json
# Data saved to /Users/katherinetian/Downloads/heart_rate/SA/heart_rate_SA_1207.json
# ...

# %% [markdown]
# ## Sleep

# %%
import requests
import json

# Define the base URL and request parameters
url = 'https://api.ouraring.com/v2/usercollection/sleep' 
params = {
    'start_date': '2024-12-01',
    'end_date': '2024-12-31'
}

# List of tokens and corresponding names
tokens = [
    {'name': 'UL_0201', 'token': 'UYX2H6CAYY4AQMVQNMZE4YOD6KPH5LLW'},
    {'name': 'UL_0225', 'token': 'BDMJI53UKMV2Y7YNDFO7A2M7T7SPMV3T'},
    {'name': 'UL_0352', 'token': '44S3FRJLZ5O4GLSW4TCFADYBLS3LF7J4'},
    {'name': 'UL_0417', 'token': 'X2JHCUYBMBWX76MGUCOLTG2QV662PNP3'},
    {'name': 'UL_0422', 'token': 'HMAPC24EX54GWTQHA5OEV3IRBVCJTNP2'},
    {'name': 'UL_0480', 'token': 'NV7PNEKQWQCWGMB27I33C7CZI7RPOSAT'},
    {'name': 'UL_1086', 'token': 'PQ4BXQMOOYADESZTUWJX7PZ6H5INMMJT'},
    {'name': 'UL_1184', 'token': 'LHOC324KTFIFSYRNOJGEI6VDK4IFOWBO'},
    {'name': 'UL_9900', 'token': '4EPJOJ6QEBRMM6S7BZJT6Q5U3D3FZKSA'}
]

# Loop through each token and make the API request
for user in tokens:
    headers = {
        'Authorization': f'Bearer {user["token"]}'  
    }

    # Make the API request
    response = requests.get(url, headers=headers, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()

        # Save the data as a JSON file with the user's name in the filename
        file_name = f'/Users/katherinetian/Downloads/sleep/UL/sleep_{user["name"]}.json'
        with open(file_name, 'w') as f:
            json.dump(data, f, indent=4)

        print(f'Data saved to {file_name}')

    else:
        # Handle possible errors
        print(f'Error with {user["name"]}: {response.status_code}')
        print(response.text)
# Out:
# Data saved to /Users/katherinetian/Downloads/sleep/UL/sleep_UL_0201.json
# Data saved to /Users/katherinetian/Downloads/sleep/UL/sleep_UL_0225.json
# Data saved to /Users/katherinetian/Downloads/sleep/UL/sleep_UL_0352.json
# Data saved to /Users/katherinetian/Downloads/sleep/UL/sleep_UL_0417.json
# Data saved to /Users/katherinetian/Downloads/sleep/UL/sleep_UL_0422.json
# Data saved to /Users/katherinetian/Downloads/sleep/UL/sleep_UL_0480.json
# Data saved to /Users/katherinetian/Downloads/sleep/UL/sleep_UL_1086.json
# Data saved to /Users/katherinetian/Downloads/sleep/UL/sleep_UL_1184.json
# Data saved to /Users/katherinetian/Downloads/sleep/UL/sleep_UL_9900.json

# %%
import requests
import json

# Define the base URL and request parameters
url = 'https://api.ouraring.com/v2/usercollection/sleep' 
params = {
    'start_date': '2024-12-01',
    'end_date': '2024-12-31'
}

# List of tokens and corresponding names
tokens = [
    {'name': 'SA_0071', 'token': 'OOAMM7TFENXQOHAJXYXVKNSOTFDRDXH2'},
    {'name': 'SA_0148', 'token': '3QRJWDU7HG64MNJVXR4AGV2G4TYFW5D2'},
    {'name': 'SA_0243', 'token': 'J7YQ57BYWLAKFGR53UYFQYY5HOFJHMLT'},
    {'name': 'SA_0528', 'token': 'MMFEOJ6VIEYRHNSRLRGVIOC73SHVI4F7'},
    {'name': 'SA_0585', 'token': 'AQMNWCP7QKC26ARO7ZBO56GJAUS2H5VF'},
    {'name': 'SA_0721', 'token': 'IH4FINABW56VPLLDUMAD7UDCNOXDX6FN'},
    {'name': 'SA_0762', 'token': 'IXO53AOR4KENUBKYGFIDAUN3EM6UAPJJ'},
    {'name': 'SA_0811', 'token': 'XDB63PKOCWZ7QNAASIEIMZQPO7NF3VH3'},
    {'name': 'SA_0820', 'token': 'LDQUFVEAP2GVSQXP5CTHZMWLAK2HLX6Y'},
    {'name': 'SA_1173', 'token': 'JNQMINIA52BKXQG5BQFGJGIOCJFMN6SR'},
    {'name': 'SA_1207', 'token': 'G3T7JPRTMKE47I3RQNEWC27R2FP4IA7T'},
    {'name': 'SA_1368', 'token': '3MLB5WN2TD7JXW3TJUPZ4BQ6RM5THTGL'}
]

# Loop through each token and make the API request
for user in tokens:
    headers = {
        'Authorization': f'Bearer {user["token"]}'  
    }

    # Make the API request
    response = requests.get(url, headers=headers, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()

        # Save the data as a JSON file with the user's name in the filename
        file_name = f'/Users/katherinetian/Downloads/sleep/SA/sleep_{user["name"]}.json'
        with open(file_name, 'w') as f:
            json.dump(data, f, indent=4)

        print(f'Data saved to {file_name}')

    else:
        # Handle possible errors
        print(f'Error with {user["name"]}: {response.status_code}')
        print(response.text)
# Out:
# Data saved to /Users/katherinetian/Downloads/sleep/SA/sleep_SA_0071.json
# Data saved to /Users/katherinetian/Downloads/sleep/SA/sleep_SA_0148.json
# Data saved to /Users/katherinetian/Downloads/sleep/SA/sleep_SA_0243.json
# Data saved to /Users/katherinetian/Downloads/sleep/SA/sleep_SA_0528.json
# Data saved to /Users/katherinetian/Downloads/sleep/SA/sleep_SA_0585.json
# Data saved to /Users/katherinetian/Downloads/sleep/SA/sleep_SA_0721.json
# Data saved to /Users/katherinetian/Downloads/sleep/SA/sleep_SA_0762.json
# Data saved to /Users/katherinetian/Downloads/sleep/SA/sleep_SA_0811.json
# Data saved to /Users/katherinetian/Downloads/sleep/SA/sleep_SA_0820.json
# Data saved to /Users/katherinetian/Downloads/sleep/SA/sleep_SA_1173.json
# Data saved to /Users/katherinetian/Downloads/sleep/SA/sleep_SA_1207.json
# Data saved to /Users/katherinetian/Downloads/sleep/SA/sleep_SA_1368.json

# %% [markdown]
# ## Daily Sleep

# %%
import requests
import json

# Define the base URL and request parameters
url = 'https://api.ouraring.com/v2/usercollection/daily_sleep' 
params = {
    'start_date': '2024-12-01',
    'end_date': '2024-12-31'
}

# List of tokens and corresponding names
tokens = [
    {'name': 'UL_0201', 'token': 'UYX2H6CAYY4AQMVQNMZE4YOD6KPH5LLW'},
    {'name': 'UL_0225', 'token': 'BDMJI53UKMV2Y7YNDFO7A2M7T7SPMV3T'},
    {'name': 'UL_0352', 'token': '44S3FRJLZ5O4GLSW4TCFADYBLS3LF7J4'},
    {'name': 'UL_0417', 'token': 'X2JHCUYBMBWX76MGUCOLTG2QV662PNP3'},
    {'name': 'UL_0422', 'token': 'HMAPC24EX54GWTQHA5OEV3IRBVCJTNP2'},
    {'name': 'UL_0480', 'token': 'NV7PNEKQWQCWGMB27I33C7CZI7RPOSAT'},
    {'name': 'UL_1086', 'token': 'PQ4BXQMOOYADESZTUWJX7PZ6H5INMMJT'},
    {'name': 'UL_1184', 'token': 'LHOC324KTFIFSYRNOJGEI6VDK4IFOWBO'},
    {'name': 'UL_9900', 'token': '4EPJOJ6QEBRMM6S7BZJT6Q5U3D3FZKSA'}
]

# Loop through each token and make the API request
for user in tokens:
    headers = {
        'Authorization': f'Bearer {user["token"]}'  
    }

    # Make the API request
    response = requests.get(url, headers=headers, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()

        # Save the data as a JSON file with the user's name in the filename
        file_name = f'/Users/katherinetian/Downloads/daily_sleep/UL/daily_sleep_{user["name"]}.json'
        with open(file_name, 'w') as f:
            json.dump(data, f, indent=4)

        print(f'Data saved to {file_name}')

    else:
        # Handle possible errors
        print(f'Error with {user["name"]}: {response.status_code}')
        print(response.text)
# Out:
# Data saved to /Users/katherinetian/Downloads/daily_sleep/UL/daily_sleep_UL_0201.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/UL/daily_sleep_UL_0225.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/UL/daily_sleep_UL_0352.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/UL/daily_sleep_UL_0417.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/UL/daily_sleep_UL_0422.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/UL/daily_sleep_UL_0480.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/UL/daily_sleep_UL_1086.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/UL/daily_sleep_UL_1184.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/UL/daily_sleep_UL_9900.json

# %%
import requests
import json

# Define the base URL and request parameters
url = 'https://api.ouraring.com/v2/usercollection/daily_sleep' 
params = {
    'start_date': '2024-12-01',
    'end_date': '2024-12-31'
}

# List of tokens and corresponding names
tokens = [
    {'name': 'SA_0071', 'token': 'OOAMM7TFENXQOHAJXYXVKNSOTFDRDXH2'},
    {'name': 'SA_0148', 'token': '3QRJWDU7HG64MNJVXR4AGV2G4TYFW5D2'},
    {'name': 'SA_0243', 'token': 'J7YQ57BYWLAKFGR53UYFQYY5HOFJHMLT'},
    {'name': 'SA_0528', 'token': 'MMFEOJ6VIEYRHNSRLRGVIOC73SHVI4F7'},
    {'name': 'SA_0585', 'token': 'AQMNWCP7QKC26ARO7ZBO56GJAUS2H5VF'},
    {'name': 'SA_0721', 'token': 'IH4FINABW56VPLLDUMAD7UDCNOXDX6FN'},
    {'name': 'SA_0762', 'token': 'IXO53AOR4KENUBKYGFIDAUN3EM6UAPJJ'},
    {'name': 'SA_0811', 'token': 'XDB63PKOCWZ7QNAASIEIMZQPO7NF3VH3'},
    {'name': 'SA_0820', 'token': 'LDQUFVEAP2GVSQXP5CTHZMWLAK2HLX6Y'},
    {'name': 'SA_1173', 'token': 'JNQMINIA52BKXQG5BQFGJGIOCJFMN6SR'},
    {'name': 'SA_1207', 'token': 'G3T7JPRTMKE47I3RQNEWC27R2FP4IA7T'},
    {'name': 'SA_1368', 'token': '3MLB5WN2TD7JXW3TJUPZ4BQ6RM5THTGL'}
]

# Loop through each token and make the API request
for user in tokens:
    headers = {
        'Authorization': f'Bearer {user["token"]}'  
    }

    # Make the API request
    response = requests.get(url, headers=headers, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()

        # Save the data as a JSON file with the user's name in the filename
        file_name = f'/Users/katherinetian/Downloads/daily_sleep/SA/daily_sleep_{user["name"]}.json'
        with open(file_name, 'w') as f:
            json.dump(data, f, indent=4)

        print(f'Data saved to {file_name}')

    else:
        # Handle possible errors
        print(f'Error with {user["name"]}: {response.status_code}')
        print(response.text)
# Out:
# Data saved to /Users/katherinetian/Downloads/daily_sleep/SA/daily_sleep_SA_0071.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/SA/daily_sleep_SA_0148.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/SA/daily_sleep_SA_0243.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/SA/daily_sleep_SA_0528.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/SA/daily_sleep_SA_0585.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/SA/daily_sleep_SA_0721.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/SA/daily_sleep_SA_0762.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/SA/daily_sleep_SA_0811.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/SA/daily_sleep_SA_0820.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/SA/daily_sleep_SA_1173.json
# Data saved to /Users/katherinetian/Downloads/daily_sleep/SA/daily_sleep_SA_1207.json
# ...
